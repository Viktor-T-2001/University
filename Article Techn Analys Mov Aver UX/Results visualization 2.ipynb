# %%
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
import missingno as msno
import numpy as np

# %%
columns = ['Тип','Параметр','Результат']
#df = pd.read_excel('Довоєнні результати.xlsx', header = None, skiprows = 1, names = columns)
df = pd.read_excel('Результати після 24_02.xlsx', header = None, skiprows = 1, names = columns)
df.head()
# Out:
#    Тип  Параметр  Результат
# 0  SMA         2  29.241252
# 1  SMA         3  40.859898
# 2  SMA         4  48.389144
# 3  SMA         5  60.049602
# 4  SMA         6  46.062132

# %%
max_value = max(df["Результат"])
fig, axs = plt.subplots(1, 3, figsize=(20, 5))
plt.rcParams.update({'font.size': 16})

plot1 = plt.subplot2grid((1, 6), (0, 0), colspan=2) 
plot2 = plt.subplot2grid((1, 6), (0, 2), colspan=2) 
plot3 = plt.subplot2grid((1, 6), (0, 4), colspan=2) 
    
plot1.plot(df["Параметр"].loc[(df['Тип']=='SMA')], df["Результат"].loc[(df['Тип']=='SMA')], color='red', linewidth=1.2, drawstyle="steps-post")
plot1.set_ylim(0, max_value*1.05)
plot1.set_title('SMA') 
plot1.set_ylabel('\nРезультат')

plot2.plot(df["Параметр"].loc[(df['Тип']=='EMA')], df["Результат"].loc[(df['Тип']=='EMA')], color='red', linewidth=1.2, drawstyle="steps-post")
plot2.set_ylim(0, max_value*1.05)
plot2.set_title('EMA')
plot2.set_xlabel('\nЗначення параметра n')

plot3.plot(df["Параметр"].loc[(df['Тип']=='LWMA')], df["Результат"].loc[(df['Тип']=='LWMA')], color='red', linewidth=1.2, drawstyle="steps-post")
plot3.set_ylim(0, max_value*1.05)
plot3.set_title('LWMA')
  
plt.tight_layout() 
plt.show() 
plt.savefig("test")

# %%
plt.figure(figsize=(20,5))
plt.rcParams.update({'font.size': 14})
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_ylim([0,1.05*max(df["Результат"].loc[(df['Тип']=='SMA')])])
plt.plot(df["Параметр"].loc[(df['Тип']=='SMA')], df["Результат"].loc[(df['Тип']=='SMA')], color='red', linewidth=1.5, drawstyle="steps-post")
plt.ylabel('\nРезультат торгової стратегії')
plt.xlabel('\nПараметр n')
# Out:
# Text(0.5, 0, '\nПараметр n')

# %%
plt.figure(figsize=(20,5))
plt.rcParams.update({'font.size': 14})
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_ylim([0,1.05*max(df["Результат"].loc[(df['Тип']=='EMA')])])
plt.plot(df["Параметр"].loc[(df['Тип']=='EMA')], df["Результат"].loc[(df['Тип']=='EMA')], color='red', linewidth=1.5, drawstyle="steps-post")
plt.ylabel('\nРезультат торгової стратегії')
plt.xlabel('\nПараметр n')
# Out:
# Text(0.5, 0, '\nПараметр n')

# %%
plt.figure(figsize=(20,5))
plt.rcParams.update({'font.size': 14})
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_ylim([0,1.05*max(df["Результат"].loc[(df['Тип']=='LWMA')])])
plt.plot(df["Параметр"].loc[(df['Тип']=='LWMA')], df["Результат"].loc[(df['Тип']=='LWMA')], color='red', linewidth=1.5, drawstyle="steps-post")
plt.ylabel('\nРезультат торгової стратегії')
plt.xlabel('\nПараметр n')
# Out:
# Text(0.5, 0, '\nПараметр n')

# %%
columns = ['Тип','Параметр','Результат']
df = pd.read_excel('Довоєнні результати.xlsx', header = None, skiprows = 1, names = columns)
#df = pd.read_excel('Результати після 24_02.xlsx', header = None, skiprows = 1, names = columns)
df.head()
# Out:
#    Тип  Параметр  Результат
# 0  SMA         2  74.982671
# 1  SMA         3  96.993242
# 2  SMA         4  60.519468
# 3  SMA         5  59.103510
# 4  SMA         6  63.062883

# %%
plt.figure(figsize=(20,5))
plt.rcParams.update({'font.size': 14})
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_ylim([0,1.05*max(df["Результат"].loc[(df['Тип']=='SMA')])])
plt.plot(df["Параметр"].loc[(df['Тип']=='SMA')], df["Результат"].loc[(df['Тип']=='SMA')], color='navy', linewidth=1.5, drawstyle="steps-post")
plt.ylabel('\nРезультат торгової стратегії')
plt.xlabel('\nПараметр n')
# Out:
# Text(0.5, 0, '\nПараметр n')

# %%
plt.figure(figsize=(20,5))
plt.rcParams.update({'font.size': 14})
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_ylim([0,1.05*max(df["Результат"].loc[(df['Тип']=='EMA')])])
plt.plot(df["Параметр"].loc[(df['Тип']=='EMA')], df["Результат"].loc[(df['Тип']=='EMA')], color='navy', linewidth=1.5, drawstyle="steps-post")
plt.ylabel('\nРезультат торгової стратегії')
plt.xlabel('\nПараметр n')
# Out:
# Text(0.5, 0, '\nПараметр n')

# %%
plt.figure(figsize=(20,5))
plt.rcParams.update({'font.size': 14})
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_ylim([0,1.05*max(df["Результат"].loc[(df['Тип']=='LWMA')])])
plt.plot(df["Параметр"].loc[(df['Тип']=='LWMA')], df["Результат"].loc[(df['Тип']=='LWMA')], color='navy', linewidth=1.5, drawstyle="steps-post")
plt.ylabel('\nРезультат торгової стратегії')
plt.xlabel('\nПараметр n')
# Out:
# Text(0.5, 0, '\nПараметр n')

# %%
columns = ['Тип','Параметр','Результат','Комісійні']
df = pd.read_excel('Довоєнні результати з комісійними.xlsx', header = None, skiprows = 1, names = columns)
#df = pd.read_excel('Результати після 24_02.xlsx', header = None, skiprows = 1, names = columns)
df.head()
# Out:
#    Тип  Параметр  Результат       Комісійні
# 0  SMA         2  74.982671  без комісійних
# 1  SMA         3  96.993242  без комісійних
# 2  SMA         4  60.519468  без комісійних
# 3  SMA         5  59.103510  без комісійних
# 4  SMA         6  63.062883  без комісійних

# %%
plt.figure(figsize=(20,5))
plt.rcParams.update({'font.size': 14})
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_ylim([0,1.05*max(df["Результат"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='без комісійних')])])
plt.plot(df["Параметр"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='без комісійних')], df["Результат"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='без комісійних')], linewidth=1.5, color="navy",drawstyle="steps-post", label="без комісійних")
plt.plot(df["Параметр"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='комісійні - 0.2%')], df["Результат"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='комісійні - 0.2%')], linewidth=1.2, color="purple",drawstyle="steps-post", label="комісійні - 0.2%")
plt.plot(df["Параметр"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='комісійні - 0.4%')], df["Результат"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='комісійні - 0.4%')], linewidth=1.2, color="red",drawstyle="steps-post", label="комісійні - 0.4%")
plt.legend(loc="lower right")
plt.ylabel('\nРезультат торгової стратегії')
plt.xlabel('\nПараметр n')
# Out:
# Text(0.5, 0, '\nПараметр n')

# %%
plt.figure(figsize=(20,5))
plt.rcParams.update({'font.size': 14})
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_ylim([0,1.05*max(df["Результат"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='без комісійних')])])
plt.plot(df["Параметр"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='без комісійних')], df["Результат"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='без комісійних')], linewidth=1.5, color="navy",drawstyle="steps-post", label="без комісійних")
plt.plot(df["Параметр"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='комісійні - 0.2%')], df["Результат"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='комісійні - 0.2%')], linewidth=1.2, color="purple",drawstyle="steps-post", label="комісійні - 0.2%")
plt.plot(df["Параметр"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='комісійні - 0.4%')], df["Результат"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='комісійні - 0.4%')], linewidth=1.2, color="red",drawstyle="steps-post", label="комісійні - 0.4%")
plt.legend(loc="lower right")
plt.ylabel('\nРезультат торгової стратегії')
plt.xlabel('\nПараметр n')
# Out:
# Text(0.5, 0, '\nПараметр n')

# %%
plt.figure(figsize=(20,5))
plt.rcParams.update({'font.size': 14})
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_ylim([0,1.05*max(df["Результат"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='без комісійних')])])
plt.plot(df["Параметр"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='без комісійних')], df["Результат"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='без комісійних')], linewidth=1.5, color="navy",drawstyle="steps-post", label="без комісійних")
plt.plot(df["Параметр"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='комісійні - 0.2%')], df["Результат"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='комісійні - 0.2%')], linewidth=1.2, color="purple",drawstyle="steps-post", label="комісійні - 0.2%")
plt.plot(df["Параметр"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='комісійні - 0.4%')], df["Результат"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='комісійні - 0.4%')], linewidth=1.2, color="red",drawstyle="steps-post", label="комісійні - 0.4%")
plt.legend(loc="lower right")
plt.ylabel('\nРезультат торгової стратегії')
plt.xlabel('\nПараметр n')
# Out:
# Text(0.5, 0, '\nПараметр n')

# %%
plt.figure(figsize=(20,5))
plt.rcParams.update({'font.size': 14})
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_ylim([0,1.05*max(df["Результат"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='без комісійних')])])
plt.plot(df["Параметр"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='без комісійних')], df["Результат"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='без комісійних')], linewidth=1.5, color="navy",drawstyle="steps-post", label="без комісійних")
plt.plot(df["Параметр"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='комісійні - 0.1%')], df["Результат"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='комісійні - 0.1%')], linewidth=1.2, color="red",drawstyle="steps-post", label="комісійні - 0.1%")
plt.plot(df["Параметр"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='комісійні - 0.3%')], df["Результат"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='комісійні - 0.3%')], linewidth=1.2, color="darkorange",drawstyle="steps-post", label="комісійні - 0.3%")
plt.legend(loc="lower right")
plt.ylabel('\nРезультат торгової стратегії')
plt.xlabel('\nПараметр n')
# Out:
# Text(0.5, 0, '\nПараметр n')

# %%
plt.figure(figsize=(20,5))
plt.rcParams.update({'font.size': 14})
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_ylim([0,1.05*max(df["Результат"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='без комісійних')])])
plt.plot(df["Параметр"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='без комісійних')], df["Результат"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='без комісійних')], linewidth=1.5, color="navy",drawstyle="steps-post", label="без комісійних")
plt.plot(df["Параметр"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='комісійні - 0.1%')], df["Результат"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='комісійні - 0.1%')], linewidth=1.2, color="red",drawstyle="steps-post", label="комісійні - 0.1%")
plt.plot(df["Параметр"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='комісійні - 0.3%')], df["Результат"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='комісійні - 0.3%')], linewidth=1.2, color="darkorange",drawstyle="steps-post", label="комісійні - 0.3%")
plt.legend(loc="lower right")
plt.ylabel('\nРезультат торгової стратегії')
plt.xlabel('\nПараметр n')
# Out:
# Text(0.5, 0, '\nПараметр n')

# %%
plt.figure(figsize=(20,5))
plt.rcParams.update({'font.size': 14})
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_ylim([0,1.05*max(df["Результат"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='без комісійних')])])
plt.plot(df["Параметр"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='без комісійних')], df["Результат"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='без комісійних')], linewidth=1.5, color="navy",drawstyle="steps-post", label="без комісійних")
plt.plot(df["Параметр"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='комісійні - 0.1%')], df["Результат"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='комісійні - 0.1%')], linewidth=1.2, color="red",drawstyle="steps-post", label="комісійні - 0.1%")
plt.plot(df["Параметр"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='комісійні - 0.3%')], df["Результат"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='комісійні - 0.3%')], linewidth=1.2, color="darkorange",drawstyle="steps-post", label="комісійні - 0.3%")
plt.legend(loc="lower right")
plt.ylabel('\nРезультат торгової стратегії')
plt.xlabel('\nПараметр n')
# Out:
# Text(0.5, 0, '\nПараметр n')

# %%
plt.figure(figsize=(20,5))
plt.rcParams.update({'font.size': 14})
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_ylim([0,1.05*max(df["Результат"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='без комісійних')])])
plt.plot(df["Параметр"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='без комісійних')], df["Результат"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='без комісійних')], linewidth=1.5, color="navy",drawstyle="steps-post", label="без комісійних")
plt.plot(df["Параметр"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='комісійні - 1%')], df["Результат"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='комісійні - 1%')], linewidth=1.2, color="darkorange",drawstyle="steps-post", label="комісійні - 1%")
plt.legend(loc="lower right")
plt.ylabel('\nРезультат торгової стратегії')
plt.xlabel('\nПараметр n')
# Out:
# Text(0.5, 0, '\nПараметр n')

# %%
plt.figure(figsize=(20,5))
plt.rcParams.update({'font.size': 14})
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_ylim([0,1.05*max(df["Результат"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='без комісійних')])])
plt.plot(df["Параметр"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='без комісійних')], df["Результат"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='без комісійних')], linewidth=1.5, color="navy",drawstyle="steps-post", label="без комісійних")
plt.plot(df["Параметр"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='комісійні - 1%')], df["Результат"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='комісійні - 1%')], linewidth=1.2, color="darkorange",drawstyle="steps-post", label="комісійні - 1%")
plt.legend(loc="lower right")
plt.ylabel('\nРезультат торгової стратегії')
plt.xlabel('\nПараметр n')
# Out:
# Text(0.5, 0, '\nПараметр n')

# %%
plt.figure(figsize=(20,5))
plt.rcParams.update({'font.size': 14})
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_ylim([0,1.05*max(df["Результат"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='без комісійних')])])
plt.plot(df["Параметр"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='без комісійних')], df["Результат"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='без комісійних')], linewidth=1.5, color="navy",drawstyle="steps-post", label="без комісійних")
plt.plot(df["Параметр"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='комісійні - 1%')], df["Результат"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='комісійні - 1%')], linewidth=1.2, color="darkorange",drawstyle="steps-post", label="комісійні - 1%")
plt.legend(loc="lower right")
plt.ylabel('\nРезультат торгової стратегії')
plt.xlabel('\nПараметр n')
# Out:
# Text(0.5, 0, '\nПараметр n')

# %%
columns = ['Тип','Параметр','Результат','Комісійні']
df = pd.read_excel('Результати після 24_02 з комісійними.xlsx', header = None, skiprows = 1, names = columns)
#df = pd.read_excel('Результати після 24_02.xlsx', header = None, skiprows = 1, names = columns)
df.head()
# Out:
#    Тип  Параметр  Результат       Комісійні
# 0  SMA         2  29.241252  без комісійних
# 1  SMA         3  40.859898  без комісійних
# 2  SMA         4  48.389144  без комісійних
# 3  SMA         5  60.049602  без комісійних
# 4  SMA         6  46.062132  без комісійних

# %%
plt.figure(figsize=(20,5))
plt.rcParams.update({'font.size': 14})
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_ylim([0,1.05*max(df["Результат"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='без комісійних')])])
plt.plot(df["Параметр"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='без комісійних')], df["Результат"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='без комісійних')], linewidth=1.5, color="navy",drawstyle="steps-post", label="без комісійних")
plt.plot(df["Параметр"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='комісійні - 0.2%')], df["Результат"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='комісійні - 0.2%')], linewidth=1.2, color="purple",drawstyle="steps-post", label="комісійні - 0.2%")
plt.plot(df["Параметр"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='комісійні - 0.4%')], df["Результат"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='комісійні - 0.4%')], linewidth=1.2, color="red",drawstyle="steps-post", label="комісійні - 0.4%")
plt.legend(loc="lower right")
plt.ylabel('\nРезультат торгової стратегії')
plt.xlabel('\nПараметр n')
# Out:
# Text(0.5, 0, '\nПараметр n')

# %%
plt.figure(figsize=(20,5))
plt.rcParams.update({'font.size': 14})
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_ylim([0,1.05*max(df["Результат"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='без комісійних')])])
plt.plot(df["Параметр"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='без комісійних')], df["Результат"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='без комісійних')], linewidth=1.5, color="navy",drawstyle="steps-post", label="без комісійних")
plt.plot(df["Параметр"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='комісійні - 0.2%')], df["Результат"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='комісійні - 0.2%')], linewidth=1.2, color="purple",drawstyle="steps-post", label="комісійні - 0.2%")
plt.plot(df["Параметр"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='комісійні - 0.4%')], df["Результат"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='комісійні - 0.4%')], linewidth=1.2, color="red",drawstyle="steps-post", label="комісійні - 0.4%")
plt.legend(loc="lower right")
plt.ylabel('\nРезультат торгової стратегії')
plt.xlabel('\nПараметр n')
# Out:
# Text(0.5, 0, '\nПараметр n')

# %%
plt.figure(figsize=(20,5))
plt.rcParams.update({'font.size': 14})
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_ylim([0,1.05*max(df["Результат"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='без комісійних')])])
plt.plot(df["Параметр"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='без комісійних')], df["Результат"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='без комісійних')], linewidth=1.5, color="navy",drawstyle="steps-post", label="без комісійних")
plt.plot(df["Параметр"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='комісійні - 0.2%')], df["Результат"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='комісійні - 0.2%')], linewidth=1.2, color="purple",drawstyle="steps-post", label="комісійні - 0.2%")
plt.plot(df["Параметр"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='комісійні - 0.4%')], df["Результат"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='комісійні - 0.4%')], linewidth=1.2, color="red",drawstyle="steps-post", label="комісійні - 0.4%")
plt.legend(loc="lower right")
plt.ylabel('\nРезультат торгової стратегії')
plt.xlabel('\nПараметр n')
# Out:
# Text(0.5, 0, '\nПараметр n')

# %%
plt.figure(figsize=(20,5))
plt.rcParams.update({'font.size': 14})
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_ylim([0,1.05*max(df["Результат"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='без комісійних')])])
plt.plot(df["Параметр"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='без комісійних')], df["Результат"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='без комісійних')], linewidth=1.5, color="navy",drawstyle="steps-post", label="без комісійних")
plt.plot(df["Параметр"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='комісійні - 0.1%')], df["Результат"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='комісійні - 0.1%')], linewidth=1.2, color="red",drawstyle="steps-post", label="комісійні - 0.1%")
plt.plot(df["Параметр"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='комісійні - 0.3%')], df["Результат"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='комісійні - 0.3%')], linewidth=1.2, color="darkorange",drawstyle="steps-post", label="комісійні - 0.3%")
plt.legend(loc="lower right")
plt.ylabel('\nРезультат торгової стратегії')
plt.xlabel('\nПараметр n')
# Out:
# Text(0.5, 0, '\nПараметр n')

# %%
plt.figure(figsize=(20,5))
plt.rcParams.update({'font.size': 14})
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_ylim([0,1.05*max(df["Результат"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='без комісійних')])])
plt.plot(df["Параметр"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='без комісійних')], df["Результат"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='без комісійних')], linewidth=1.5, color="navy",drawstyle="steps-post", label="без комісійних")
plt.plot(df["Параметр"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='комісійні - 0.1%')], df["Результат"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='комісійні - 0.1%')], linewidth=1.2, color="red",drawstyle="steps-post", label="комісійні - 0.1%")
plt.plot(df["Параметр"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='комісійні - 0.3%')], df["Результат"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='комісійні - 0.3%')], linewidth=1.2, color="darkorange",drawstyle="steps-post", label="комісійні - 0.3%")
plt.legend(loc="lower right")
plt.ylabel('\nРезультат торгової стратегії')
plt.xlabel('\nПараметр n')
# Out:
# Text(0.5, 0, '\nПараметр n')

# %%
plt.figure(figsize=(20,5))
plt.rcParams.update({'font.size': 14})
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_ylim([0,1.05*max(df["Результат"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='без комісійних')])])
plt.plot(df["Параметр"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='без комісійних')], df["Результат"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='без комісійних')], linewidth=1.5, color="navy",drawstyle="steps-post", label="без комісійних")
plt.plot(df["Параметр"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='комісійні - 0.1%')], df["Результат"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='комісійні - 0.1%')], linewidth=1.2, color="red",drawstyle="steps-post", label="комісійні - 0.1%")
plt.plot(df["Параметр"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='комісійні - 0.3%')], df["Результат"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='комісійні - 0.3%')], linewidth=1.2, color="darkorange",drawstyle="steps-post", label="комісійні - 0.3%")
plt.legend(loc="lower right")
plt.ylabel('\nРезультат торгової стратегії')
plt.xlabel('\nПараметр n')
# Out:
# Text(0.5, 0, '\nПараметр n')

# %%
plt.figure(figsize=(20,5))
plt.rcParams.update({'font.size': 14})
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_ylim([0,1.05*max(df["Результат"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='без комісійних')])])
plt.plot(df["Параметр"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='без комісійних')], df["Результат"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='без комісійних')], linewidth=1.5, color="navy",drawstyle="steps-post", label="без комісійних")
plt.plot(df["Параметр"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='комісійні - 1%')], df["Результат"].loc[(df['Тип']=='SMA')&(df['Комісійні']=='комісійні - 1%')], linewidth=1.2, color="darkorange",drawstyle="steps-post", label="комісійні - 1%")
plt.legend(loc="lower right")
plt.ylabel('\nРезультат торгової стратегії')
plt.xlabel('\nПараметр n')
# Out:
# Text(0.5, 0, '\nПараметр n')

# %%
plt.figure(figsize=(20,5))
plt.rcParams.update({'font.size': 14})
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_ylim([0,1.05*max(df["Результат"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='без комісійних')])])
plt.plot(df["Параметр"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='без комісійних')], df["Результат"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='без комісійних')], linewidth=1.5, color="navy",drawstyle="steps-post", label="без комісійних")
plt.plot(df["Параметр"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='комісійні - 1%')], df["Результат"].loc[(df['Тип']=='EMA')&(df['Комісійні']=='комісійні - 1%')], linewidth=1.2, color="darkorange",drawstyle="steps-post", label="комісійні - 1%")
plt.legend(loc="lower right")
plt.ylabel('\nРезультат торгової стратегії')
plt.xlabel('\nПараметр n')
# Out:
# Text(0.5, 0, '\nПараметр n')

# %%
plt.figure(figsize=(20,5))
plt.rcParams.update({'font.size': 14})
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_ylim([0,1.05*max(df["Результат"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='без комісійних')])])
plt.plot(df["Параметр"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='без комісійних')], df["Результат"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='без комісійних')], linewidth=1.5, color="navy",drawstyle="steps-post", label="без комісійних")
plt.plot(df["Параметр"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='комісійні - 1%')], df["Результат"].loc[(df['Тип']=='LWMA')&(df['Комісійні']=='комісійні - 1%')], linewidth=1.2, color="darkorange",drawstyle="steps-post", label="комісійні - 1%")
plt.legend(loc="lower right")
plt.ylabel('\nРезультат торгової стратегії')
plt.xlabel('\nПараметр n')
# Out:
# Text(0.5, 0, '\nПараметр n')
