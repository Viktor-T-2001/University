# %%
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
import missingno as msno
import numpy as np

# %%
columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Volume']
df = pd.read_excel('Вхідні дані.xlsx', header = None, skiprows = 1, names = columns)
df.index = df["Date"]
df.index = pd.to_datetime(df.index)
df.head()
# Out:
#                  Date     Open     High      Low    Close  Volume
# Date
# 2024-07-05 2024-07-05  1194.15  1194.15  1194.15  1194.15     NaN
# 2024-07-04 2024-07-04  1194.15  1194.15  1194.15  1194.15     NaN
# 2024-07-03 2024-07-03  1194.15  1194.15  1194.15  1194.15     NaN
# 2024-07-02 2024-07-02  1194.15  1194.15  1194.15  1194.15     NaN
# 2024-07-01 2024-07-01  1194.15  1194.15  1194.15  1194.15  6240.0

# %% [markdown]
# ### **Історичні значення індексу UX (з 24-02-2024 по 05-07-2024)**

# %%
start_date = pd.to_datetime('2022-2-25')
plt.rcParams.update({'font.size': 13})
df1 = df.loc[df['Date']>= start_date]
stock_data = df1.set_index('Date')
plt.figure(figsize=(20,10))
ax = plt.axes()
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)
plt.xlabel('\nДата')
plt.ylabel('\nЗначення індексу')
plt.plot(stock_data.index, stock_data["Close"], color='navy', linewidth=1.5)
#plt.title('Історичні значення індексу UX (з 24-02-2024 по 05-07-2024)', {'size' : 15})

# %% [markdown]
# ### **Динаміка сумарного обєму торгів за день**

# %%
plt.rcParams.update({'font.size': 13})
plt.figure(figsize=(20,5))
#bottom_plt = plt.subplot2grid((5,4), (3,0), rowspan=1, colspan=4)
plt.bar(stock_data.index, stock_data['Volume'],color='black',width=1.5)
plt.xlabel('\nДата')
plt.ylabel('\nОб\'єм торгів')
#plt.title('\nДинаміка сумарного об\'єму торгів за день')
# Out:
# Text(0, 0.5, "\nОб'єм торгів")

# %% [markdown]
# ### **Історичні значення індексу UX (з 10-09-2024 по 05-07-2024)**

# %%
start_date = pd.to_datetime('2022-8-10')
plt.rcParams.update({'font.size': 13})
df1 = df.loc[df['Date']>= start_date]
stock_data = df1.set_index('Date')
plt.figure(figsize=(20,10))
ax = plt.axes()
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)
plt.xlabel('\nДата')
plt.ylabel('\nЗначення індексу')
plt.plot(stock_data.index, stock_data["Close"], color='navy', linewidth=1.5)
#plt.title('Історичні значення індексу UX (з 10-09-2024 по 05-07-2024)', {'size' : 15})

# %% [markdown]
# ### **Пропущені значення**

# %%
msno.bar(stock_data, color = (138/225,43/225,225/225))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### **SMA**

# %%
def SMA(data,n):

  #додаємо NaN на початку
	sma_list=[np.nan for k in range(n-1)]

	for i in range(len(data)-n+1):
		sum_n = 0
		for j in range(n):
			sum_n = sum_n + data[i+j]
		sma=sum_n/n
		sma_list.append(round(sma, 2))

	return sma_list

# %% [markdown]
# ### **LWMA**

# %%
def LWMA(data,n):

	lma_list=[np.nan for k in range(n-1)]

	for i in range(len(data)-n+1):
		sum_n, sum_j = 0, 0
		for j in range(n):
			sum_n = sum_n + (j+1)*data[i+j]
			sum_j = sum_j + (j+1)
		lma=sum_n/sum_j
		lma_list.append(lma)

	return lma_list

# %% [markdown]
# ### **EMA**

# %%
def EMA(data, n, a=0):
	ema_list=[data[0]]
	if a==0:
		a=2/(n+1)

	for i in range (1,len(data)):
		ema = 0
		ema = (1-a)*ema_list[i-1]+a*data[i]
		ema_list.append(ema)

	return ema_list

# %% [markdown]
# ### **Торгова стратегія на основі перетину ціни і плинного середнього**

# %% [markdown]
# Сигнали - перетин ціни і плинного середнього
#
# P - list of Close prices
#
# n1 - к-ть періодів для середнього
#
# MA_type - тип середнього ("SMA", "EMA", "LWMA")

# %%
def strategy_MA_1(P, n1, MA_type, n2=26, n3=9):
  MA= []
  if MA_type == "SMA":
    MA = SMA(P, n1)
  elif MA_type == "EMA":
    MA = EMA(P, n1)
  elif MA_type == "LWMA":
    MA = LWMA(P, n1)

  if MA_type != "EMA":
    s=[np.nan for k in range(n1)]
    for i in range(n1, len(MA)):
      if (P[i-1]<MA[i-1]) and (P[i]>MA[i]):
        s.append(1)
      elif (P[i-1]>MA[i-1]) and (P[i]<MA[i]):
        s.append(-1)
      else:
        s.append(0)
  elif MA_type == "EMA":
    s=[np.nan]
    for i in range(1,len(MA)):
      if (P[i-1]<MA[i-1]) and (P[i]>MA[i]):
        s.append(1)
      elif (P[i-1]>MA[i-1]) and (P[i]<MA[i]):
        s.append(-1)
      else:
        s.append(0)
  return s

# %% [markdown]
# ### **Конвертація торгових сигналів**

# %%
def signal_convertation(signals):
    non_zero_element = 0
    converted_signals = []
    #елементи на початку ряду можуть бути нулями, ми їх не змінюємо до появи першого сигналу

    for i in range(len(signals)):
        if np.isnan(signals[i]):
            converted_signals.append(np.nan)
        else:
            if signals[i] != 0:
                non_zero_element = signals[i]
                converted_signals.append(signals[i])
            else:
                converted_signals.append(non_zero_element)

    return converted_signals

# %% [markdown]
# ### **Розрахунок результату торгової стратегії**

# %%
def trading_results(price, signal):
    results=["n/a" for i in range(len(price))]
    open_short, close_short, open_long, close_long = 0, 0, 0, 0


    for i in range(1,len(signal)):

        if signal[i] == 0 and signal[i-1] == 1:
            open_short = i
            close_long = i
            #рахуємо прибутковість довгої позиції
            result = (price[close_long] - price[open_long])/price[open_long]
            #result = (price[close_long] - price[open_long])/price[open_long] - 0.4/100
            results[i] = result

        if signal[i] == 1 and signal[i-1] == 0:
            close_short = i
            open_long = i
            #рахуємо прибутковість короткої позиції
            result = -(price[close_short] - price[open_short])/price[open_short]
            #result = -(price[close_short] - price[open_short])/price[open_short] - 0.4/100
            results[i] = result

    return(results)

# %%
start_date = pd.to_datetime('2022-8-10')
for type_ in ["SMA", "EMA", "LWMA"]:
    for n_ in range (2,101):
        
        df1 = df.loc[df['Date']>= start_date]
        stock_data = df1.set_index('Date') 
        stock_data.index = pd.to_datetime(stock_data.index)
        stock_data.drop(['Volume','Open','High','Low'], axis='columns', inplace=True)
        stock_data = stock_data.sort_index() 

        stock_data["Indicator"] = strategy_MA_1(P = stock_data.Close, n1 = n_, MA_type = type_)
        stock_data["PARAM"] = signal_convertation(stock_data["Indicator"])

        stock_data = stock_data.replace(0, np.nan)
        stock_data = stock_data.dropna()

        signal = []
        for i in range(len(stock_data["Close"])):
          if stock_data["PARAM"][i] > 0:
              signal.append(1)
          else:
              signal.append(0)

        stock_data["Signal"] = signal

        results = trading_results(stock_data["Close"], stock_data["Signal"])
        stock_data["Results"] = results

        for i in range(len(results)):
            if results[i] != 'n/a':
                results[i] = results[i]*100

        amount = []
        amount_ = 100
        for element in results:
            if element != 'n/a':
                amount_ = amount_*(1+element/100)
                amount.append(amount_)
            else:
                amount.append(element)
        amount[0] = 100

        for i in range(len(amount)):
          if amount[i] != 'n/a':
              remember = amount[i]
          else:
              amount[i] = remember

        stock_data["Amount"] = amount

        file_name = 'TA_results/UX_calculation_n_'+str(n_)+"_"+type_+'.txt'
        with open(file_name, 'a') as f:
            f.write(stock_data.to_string(header=True, index=True))

        print("Значення параметра: "+type_+" " + str(n_) +"; результат: "+str(amount[len(amount)-1]))
# Out:
# Значення параметра: SMA 2; результат: 29.241251763264984
# Значення параметра: SMA 3; результат: 40.85989818764052
# Значення параметра: SMA 4; результат: 48.38914415083879
# Значення параметра: SMA 5; результат: 60.0496016375749
# Значення параметра: SMA 6; результат: 46.06213196911969
# Значення параметра: SMA 7; результат: 50.357693800379884
# Значення параметра: SMA 8; результат: 29.20613437789868
# Значення параметра: SMA 9; результат: 26.826669185270376
# Значення параметра: SMA 10; результат: 20.57107537736757
# Значення параметра: SMA 11; результат: 15.807164784023529
# Значення параметра: SMA 12; результат: 16.296252406516192
# Значення параметра: SMA 13; результат: 16.86674153532824
# Значення параметра: SMA 14; результат: 26.472932025839736
# Значення параметра: SMA 15; результат: 29.459472504310405
# Значення параметра: SMA 16; результат: 29.064557256146013
# Значення параметра: SMA 17; результат: 31.64297888049725
# Значення параметра: SMA 18; результат: 22.675101101417084
# Значення параметра: SMA 19; результат: 20.6919801394908
# Значення параметра: SMA 20; результат: 19.65365082976164
# Значення параметра: SMA 21; результат: 29.498448143557823
# Значення параметра: SMA 22; результат: 27.662898499433776
# Значення параметра: SMA 23; результат: 24.603646335971217
# Значення параметра: SMA 24; результат: 23.65127302506213
# Значення параметра: SMA 25; результат: 67.24406952513633
# Значення параметра: SMA 26; результат: 72.35181621251601
# Значення параметра: SMA 27; результат: 80.00267868561653
# Значення параметра: SMA 28; результат: 74.92312440499659
# Значення параметра: SMA 29; результат: 92.82687438383658
# Значення параметра: SMA 30; результат: 92.13822469923221
# Значення параметра: SMA 31; результат: 83.13363520645731
# Значення параметра: SMA 32; результат: 90.62087471553156
# Значення параметра: SMA 33; результат: 88.46298714954908
# Значення параметра: SMA 34; результат: 84.3696799328369
# Значення параметра: SMA 35; результат: 64.04723904645188
# Значення параметра: SMA 36; результат: 67.53107061615258
# Значення параметра: SMA 37; результат: 67.06199891489969
# Значення параметра: SMA 38; результат: 67.26266164543074
# Значення параметра: SMA 39; результат: 77.78863389043633
# Значення параметра: SMA 40; результат: 79.52226271026214
# Значення параметра: SMA 41; результат: 69.57348818403146
# Значення параметра: SMA 42; результат: 71.19145557294233
# Значення параметра: SMA 43; результат: 71.54368460858076
# Значення параметра: SMA 44; результат: 74.46869111240929
# Значення параметра: SMA 45; результат: 74.70024116499204
# Значення параметра: SMA 46; результат: 69.35193916985565
# Значення параметра: SMA 47; результат: 78.26905704950305
# Значення параметра: SMA 48; результат: 77.21633591325053
# Значення параметра: SMA 49; результат: 77.21633591325053
# Значення параметра: SMA 50; результат: 84.06770572297204
# Значення параметра: SMA 51; результат: 87.37513203800509
# Значення параметра: SMA 52; результат: 82.86837862331019
# Значення параметра: SMA 53; результат: 82.86837862331019
# Значення параметра: SMA 54; результат: 77.49875118163942
# Значення параметра: SMA 55; результат: 79.84852509020095
# Значення параметра: SMA 56; результат: 63.37124001649733
# Значення параметра: SMA 57; результат: 62.93978021214436
# Значення параметра: SMA 58; результат: 62.93978021214436
# Значення параметра: SMA 59; результат: 63.76298617107704
# Значення параметра: SMA 60; результат: 64.20008915182477
# Значення параметра: SMA 61; результат: 64.20008915182477
# Значення параметра: SMA 62; результат: 64.20008915182477
# Значення параметра: SMA 63; результат: 69.24406945486676
# Значення параметра: SMA 64; результат: 55.59176550943541
# Значення параметра: SMA 65; результат: 52.73312012822264
# Значення параметра: SMA 66; результат: 52.73312012822264
# Значення параметра: SMA 67; результат: 52.73312012822264
# Значення параметра: SMA 68; результат: 52.73312012822264
# Значення параметра: SMA 69; результат: 57.304400830815695
# Значення параметра: SMA 70; результат: 57.304400830815695
# Значення параметра: SMA 71; результат: 57.16846528683609
# Значення параметра: SMA 72; результат: 57.16846528683609
# Значення параметра: SMA 73; результат: 20.620341094297647
# Значення параметра: SMA 74; результат: 20.95864179221774
# Значення параметра: SMA 75; результат: 21.32306682654395
# Значення параметра: SMA 76; результат: 19.537331433534074
# Значення параметра: SMA 77; результат: 58.169686515614536
# Значення параметра: SMA 78; результат: 58.169686515614536
# Значення параметра: SMA 79; результат: 58.169686515614536
# Значення параметра: SMA 80; результат: 58.169686515614536
# Значення параметра: SMA 81; результат: 54.7088608815481
# Значення параметра: SMA 82; результат: 54.7088608815481
# Значення параметра: SMA 83; результат: 54.31946260738923
# Значення параметра: SMA 84; результат: 54.31946260738923
# Значення параметра: SMA 85; результат: 54.31946260738923
# Значення параметра: SMA 86; результат: 53.89528308251275
# Значення параметра: SMA 87; результат: 53.89528308251275
# Значення параметра: SMA 88; результат: 53.91267583541503
# Значення параметра: SMA 89; результат: 54.31946260738923
# Значення параметра: SMA 90; результат: 54.7088608815481
# Значення параметра: SMA 91; результат: 54.7088608815481
# Значення параметра: SMA 92; результат: 58.59361916894881
# Значення параметра: SMA 93; результат: 52.68538533546761
# Значення параметра: SMA 94; результат: 59.22302650599561
# Значення параметра: SMA 95; результат: 59.22302650599561
# Значення параметра: SMA 96; результат: 59.22302650599561
# Значення параметра: SMA 97; результат: 59.22302650599561
# Значення параметра: SMA 98; результат: 60.648806838152794
# Значення параметра: SMA 99; результат: 60.648806838152794
# Значення параметра: SMA 100; результат: 60.648806838152794
# Значення параметра: EMA 2; результат: 50.198840075500485
# Значення параметра: EMA 3; результат: 34.77088997511961
# Значення параметра: EMA 4; результат: 34.74680649165177
# Значення параметра: EMA 5; результат: 33.29583177501135
# Значення параметра: EMA 6; результат: 31.9723621633103
# Значення параметра: EMA 7; результат: 32.792465172019604
# Значення параметра: EMA 8; результат: 32.430861938617014
# Значення параметра: EMA 9; результат: 26.371936191624794
# Значення параметра: EMA 10; результат: 24.9943169044283
# Значення параметра: EMA 11; результат: 24.753234565075704
# Значення параметра: EMA 12; результат: 23.23322361358808
# Значення параметра: EMA 13; результат: 23.09280062542841
# Значення параметра: EMA 14; результат: 37.13484280649143
# Значення параметра: EMA 15; результат: 30.90036326153895
# Значення параметра: EMA 16; результат: 49.965866374693235
# Значення параметра: EMA 17; результат: 39.64326458444844
# Значення параметра: EMA 18; результат: 35.683460384938805
# Значення параметра: EMA 19; результат: 35.683460384938805
# Значення параметра: EMA 20; результат: 36.08623001552896
# Значення параметра: EMA 21; результат: 36.08623001552896
# Значення параметра: EMA 22; результат: 34.39154302715727
# Значення параметра: EMA 23; результат: 33.990018701521414
# Значення параметра: EMA 24; результат: 32.676082359137375
# Значення параметра: EMA 25; результат: 37.490425566622356
# Значення параметра: EMA 26; результат: 37.582758062055824
# Значення параметра: EMA 27; результат: 37.582758062055824
# Значення параметра: EMA 28; результат: 39.513318624575355
# Значення параметра: EMA 29; результат: 39.70262431694522
# Значення параметра: EMA 30; результат: 41.817139231911575
# Значення параметра: EMA 31; результат: 41.670997911277375
# Значення параметра: EMA 32; результат: 116.6164114385896
# Значення параметра: EMA 33; результат: 115.26860126390174
# Значення параметра: EMA 34; результат: 116.26620670333328
# Значення параметра: EMA 35; результат: 116.26620670333328
# Значення параметра: EMA 36; результат: 116.26620670333328
# Значення параметра: EMA 37; результат: 112.14608698555023
# Значення параметра: EMA 38; результат: 116.57279141190217
# Значення параметра: EMA 39; результат: 117.62123455347331
# Значення параметра: EMA 40; результат: 138.2265808983948
# Значення параметра: EMA 41; результат: 138.2265808983948
# Значення параметра: EMA 42; результат: 138.2265808983948
# Значення параметра: EMA 43; результат: 138.2265808983948
# Значення параметра: EMA 44; результат: 127.18060389264514
# Значення параметра: EMA 45; результат: 129.32944577257453
# Значення параметра: EMA 46; результат: 99.82338080678726
# Значення параметра: EMA 47; результат: 99.82338080678726
# Значення параметра: EMA 48; результат: 91.3395829466277
# Значення параметра: EMA 49; результат: 77.91805370567741
# Значення параметра: EMA 50; результат: 77.91805370567741
# Значення параметра: EMA 51; результат: 77.37683388380042
# Значення параметра: EMA 52; результат: 77.37683388380042
# Значення параметра: EMA 53; результат: 77.37683388380042
# Значення параметра: EMA 54; результат: 77.37683388380042
# Значення параметра: EMA 55; результат: 62.146792335600914
# Значення параметра: EMA 56; результат: 62.146792335600914
# Значення параметра: EMA 57; результат: 61.617439600744035
# Значення параметра: EMA 58; результат: 65.37556039661023
# Значення параметра: EMA 59; результат: 69.05236402982716
# Значення параметра: EMA 60; результат: 69.05236402982716
# Значення параметра: EMA 61; результат: 69.70174245127012
# Значення параметра: EMA 62; результат: 71.49459772890945
# Значення параметра: EMA 63; результат: 71.49459772890945
# Значення параметра: EMA 64; результат: 71.22937948978662
# Значення параметра: EMA 65; результат: 70.12784949908959
# Значення параметра: EMA 66; результат: 70.27758964340453
# Значення параметра: EMA 67; результат: 67.71453049664252
# Значення параметра: EMA 68; результат: 67.71453049664252
# Значення параметра: EMA 69; результат: 67.71453049664252
# Значення параметра: EMA 70; результат: 67.71453049664252
# Значення параметра: EMA 71; результат: 67.71453049664252
# Значення параметра: EMA 72; результат: 67.71453049664252
# Значення параметра: EMA 73; результат: 60.90814337162053
# Значення параметра: EMA 74; результат: 62.933515927459695
# Значення параметра: EMA 75; результат: 62.933515927459695
# Значення параметра: EMA 76; результат: 62.933515927459695
# Значення параметра: EMA 77; результат: 62.933515927459695
# Значення параметра: EMA 78; результат: 62.933515927459695
# Значення параметра: EMA 79; результат: 62.27437449183418
# Значення параметра: EMA 80; результат: 62.27437449183418
# Значення параметра: EMA 81; результат: 57.74058816965475
# Значення параметра: EMA 82; результат: 57.74058816965475
# Значення параметра: EMA 83; результат: 57.74058816965475
# Значення параметра: EMA 84; результат: 57.74058816965475
# Значення параметра: EMA 85; результат: 57.74058816965475
# Значення параметра: EMA 86; результат: 57.74058816965475
# Значення параметра: EMA 87; результат: 57.74058816965475
# Значення параметра: EMA 88; результат: 57.96659239329299
# Значення параметра: EMA 89; результат: 57.96659239329299
# Значення параметра: EMA 90; результат: 57.96659239329299
# Значення параметра: EMA 91; результат: 57.96659239329299
# Значення параметра: EMA 92; результат: 57.96659239329299
# Значення параметра: EMA 93; результат: 57.96659239329299
# Значення параметра: EMA 94; результат: 54.97671264017205
# Значення параметра: EMA 95; результат: 54.97671264017205
# Значення параметра: EMA 96; результат: 51.705854092039104
# Значення параметра: EMA 97; результат: 51.705854092039104
# Значення параметра: EMA 98; результат: 51.705854092039104
# Значення параметра: EMA 99; результат: 51.705854092039104
# Значення параметра: EMA 100; результат: 51.705854092039104
# Значення параметра: LWMA 2; результат: 27.09262647676851
# Значення параметра: LWMA 3; результат: 38.33835538872625
# Значення параметра: LWMA 4; результат: 68.58719083614719
# Значення параметра: LWMA 5; результат: 79.00601881904376
# Значення параметра: LWMA 6; результат: 53.47858949223418
# Значення параметра: LWMA 7; результат: 28.045545595546585
# Значення параметра: LWMA 8; результат: 32.36179720409598
# Значення параметра: LWMA 9; результат: 40.95494683274941
# Значення параметра: LWMA 10; результат: 34.547655853089125
# Значення параметра: LWMA 11; результат: 33.066455036785115
# Значення параметра: LWMA 12; результат: 33.66168382696216
# Значення параметра: LWMA 13; результат: 27.67689091283259
# Значення параметра: LWMA 14; результат: 25.98372478590912
# Значення параметра: LWMA 15; результат: 26.46544025884683
# Значення параметра: LWMA 16; результат: 26.90589405304766
# Значення параметра: LWMA 17; результат: 26.22257737777454
# Значення параметра: LWMA 18; результат: 24.68039626631903
# Значення параметра: LWMA 19; результат: 18.745203261473186
# Значення параметра: LWMA 20; результат: 25.1749075978511
# Значення параметра: LWMA 21; результат: 24.839470831353577
# Значення параметра: LWMA 22; результат: 24.839470831353577
# Значення параметра: LWMA 23; результат: 21.273591363142117
# Значення параметра: LWMA 24; результат: 20.638378977205672
# Значення параметра: LWMA 25; результат: 19.892063222964463
# Значення параметра: LWMA 26; результат: 19.36907122558565
# Значення параметра: LWMA 27; результат: 19.36907122558566
# Значення параметра: LWMA 28; результат: 27.483741684904704
# Значення параметра: LWMA 29; результат: 25.748267982040105
# Значення параметра: LWMA 30; результат: 25.441542042568344
# Значення параметра: LWMA 31; результат: 26.06407010275774
# Значення параметра: LWMA 32; результат: 26.267609920686954
# Значення параметра: LWMA 33; результат: 27.50137040947054
# Значення параметра: LWMA 34; результат: 27.285271239327123
# Значення параметра: LWMA 35; результат: 26.55446878936726
# Значення параметра: LWMA 36; результат: 27.417523438638188
# Значення параметра: LWMA 37; результат: 27.321721476598412
# Значення параметра: LWMA 38; результат: 86.44545757750153
# Значення параметра: LWMA 39; результат: 91.00374147767562
# Значення параметра: LWMA 40; результат: 91.00374147767562
# Значення параметра: LWMA 41; результат: 90.92608287794141
# Значення параметра: LWMA 42; результат: 88.34454439924146
# Значення параметра: LWMA 43; результат: 101.09256512105169
# Значення параметра: LWMA 44; результат: 104.35650814411856
# Значення параметра: LWMA 45; результат: 104.35650814411856
# Значення параметра: LWMA 46; результат: 96.23807454013868
# Значення параметра: LWMA 47; результат: 96.67242941938416
# Значення параметра: LWMA 48; результат: 97.40254404291372
# Значення параметра: LWMA 49; результат: 89.45899978673113
# Значення параметра: LWMA 50; результат: 89.31516585995712
# Значення параметра: LWMA 51; результат: 92.49351677160176
# Значення параметра: LWMA 52; результат: 97.43590787486421
# Значення параметра: LWMA 53; результат: 99.71011813316572
# Значення параметра: LWMA 54; результат: 85.05861411956764
# Значення параметра: LWMA 55; результат: 84.45212623173184
# Значення параметра: LWMA 56; результат: 77.25798010288787
# Значення параметра: LWMA 57; результат: 76.08287424077234
# Значення параметра: LWMA 58; результат: 76.09786355485384
# Значення параметра: LWMA 59; результат: 75.41732778776372
# Значення параметра: LWMA 60; результат: 80.01712014791933
# Значення параметра: LWMA 61; результат: 88.4080056638286
# Значення параметра: LWMA 62; результат: 90.4059470969939
# Значення параметра: LWMA 63; результат: 90.4059470969939
# Значення параметра: LWMA 64; результат: 90.4059470969939
# Значення параметра: LWMA 65; результат: 90.4059470969939
# Значення параметра: LWMA 66; результат: 90.4059470969939
# Значення параметра: LWMA 67; результат: 85.86999482756127
# Значення параметра: LWMA 68; результат: 90.04192460334615
# Значення параметра: LWMA 69; результат: 90.04192460334615
# Значення параметра: LWMA 70; результат: 90.04192460334615
# Значення параметра: LWMA 71; результат: 86.65909293122084
# Значення параметра: LWMA 72; результат: 90.19346834009067
# Значення параметра: LWMA 73; результат: 90.19346834009067
# Значення параметра: LWMA 74; результат: 83.62707700421548
# Значення параметра: LWMA 75; результат: 83.62707700421548
# Значення параметра: LWMA 76; результат: 85.04003904294291
# Значення параметра: LWMA 77; результат: 65.6384487731866
# Значення параметра: LWMA 78; результат: 65.6384487731866
# Значення параметра: LWMA 79; результат: 64.32937978819434
# Значення параметра: LWMA 80; результат: 64.32937978819434
# Значення параметра: LWMA 81; результат: 64.32937978819434
# Значення параметра: LWMA 82; результат: 63.65561861147313
# Значення параметра: LWMA 83; результат: 63.65561861147313
# Значення параметра: LWMA 84; результат: 65.97814831247963
# Значення параметра: LWMA 85; результат: 65.97814831247963
# Значення параметра: LWMA 86; результат: 65.97814831247963
# Значення параметра: LWMA 87; результат: 65.97814831247963
# Значення параметра: LWMA 88; результат: 65.97814831247963
# Значення параметра: LWMA 89; результат: 65.97814831247963
# Значення параметра: LWMA 90; результат: 65.97814831247963
# Значення параметра: LWMA 91; результат: 67.82868393722491
# Значення параметра: LWMA 92; результат: 67.82868393722491
# Значення параметра: LWMA 93; результат: 67.82868393722491
# Значення параметра: LWMA 94; результат: 67.82868393722491
# Значення параметра: LWMA 95; результат: 64.3301238112684
# Значення параметра: LWMA 96; результат: 64.3301238112684
# Значення параметра: LWMA 97; результат: 64.3301238112684
# Значення параметра: LWMA 98; результат: 63.02103968579858
# Значення параметра: LWMA 99; результат: 63.02103968579858
# Значення параметра: LWMA 100; результат: 63.02103968579858
